# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
DATA_DIR = Path("data")

# %%
# CSVs
csv = pd.read_csv(DATA_DIR / "participants.csv")

# %%
print(f"{csv.head() = }\n")
print(f"{csv.shape = }\n")
print(f"{csv.dtypes = }\n")
print(f"{csv.info() = }\n")
# Out:
# csv.head() =     id  age group  score
# 0  101   24     A     81
# 1  102   31     B     94
# 2  103   27     A     88
#
# csv.shape = (3, 4)
#
# csv.dtypes = id       int64
# age      int64
# group      str
# score    int64
# dtype: object
#
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   age     3 non-null      int64
#  2   group   3 non-null      str
#  3   score   3 non-null      int64
# dtypes: int64(3), str(1)
# memory usage: 231.0 bytes
# csv.info() = None

# %%
# SQL / SQLite3
